# %%
# app.py
import streamlit as st
import pandas as pd
import numpy as np
import joblib

# Load model artifacts
model = joblib.load("kmeans_model.pkl")
scaler = joblib.load("scaler.pkl")
feature_names = joblib.load("feature_names.pkl")

st.set_page_config(page_title="Customer Cluster Predictor")
st.title("🧠 Customer Segmentation Dashboard")

st.markdown("Enter customer details to predict the cluster they belong to.")

# Sidebar inputs
st.sidebar.header("Customer Details")

age = st.sidebar.slider("Age", 18, 90, 35)
income = st.sidebar.number_input("Income", 1000, 200000, 40000, step=1000)
kidhome = st.sidebar.selectbox("Kids at Home", [0, 1, 2])
teenhome = st.sidebar.selectbox("Teens at Home", [0, 1, 2])
recency = st.sidebar.slider("Recency (days)", 0, 100, 30)
mntwines = st.sidebar.slider("Amount Spent on Wine", 0, 1000, 150)
mntmeat = st.sidebar.slider("Amount Spent on Meat", 0, 1000, 200)
mntgold = st.sidebar.slider("Amount Spent on Gold", 0, 1000, 50)
webvisits = st.sidebar.slider("Web Visits per Month", 0, 20, 5)

# Categorical features
education = st.sidebar.selectbox("Education Level", ['Graduation', 'PhD', 'Master', 'Basic'])
marital_status = st.sidebar.selectbox("Marital Status", ['Single', 'Married', 'Together', 'Divorced', 'Widow'])

# Base input dict
input_data = {
    'Year_Birth': [2024 - age],
    'Income': [income],
    'Kidhome': [kidhome],
    'Teenhome': [teenhome],
    'Recency': [recency],
    'MntWines': [mntwines],
    'MntMeatProducts': [mntmeat],
    'MntGoldProds': [mntgold],
    'NumWebVisitsMonth': [webvisits],
    'Education_' + education: [1],
    'Marital_Status_' + marital_status: [1],
}

# Create a DataFrame with all zeros for every feature in training
input_df = pd.DataFrame(columns=feature_names)
input_df.loc[0] = 0  # Fill first row with zeros

# Fill real values into appropriate columns
for key, value in input_data.items():
    if key in input_df.columns:
        input_df[key] = value

# Scale the input
scaled_input = scaler.transform(input_df)

# Predict cluster
if st.button("Predict Cluster"):
    cluster = model.predict(scaled_input)[0]
    st.success(f"🎯 This customer belongs to **Cluster {cluster}**")

    st.markdown(f"""
    ### 🔍 Cluster {cluster} Characteristics
    - Based on your inputs, this customer shares similar attributes with others in Cluster {cluster}.
    - Use this info for targeted marketing, offers, or personalization.
    """)
# Out:
# 2025-06-27 21:30:14.703 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.705 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.709 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.714 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.716 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.720 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.722 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.725 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.727 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.729 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.732 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.734 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.736 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.738 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.739 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.746 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.748 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.750 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.752 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.755 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.757 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.759 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.761 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.763 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.765 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.766 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.767 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.769 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.773 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.774 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.776 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.778 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.779 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.780 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.782 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.784 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.786 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.788 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.790 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.791 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.793 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.794 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.796 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.797 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.803 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.805 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.806 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.808 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.809 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.812 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.813 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.815 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.821 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.824 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.826 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.828 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.830 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.832 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.833 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.835 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.837 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.840 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.841 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.843 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.846 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.848 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.850 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.896 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.897 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.899 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.900 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-27 21:30:14.901 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
